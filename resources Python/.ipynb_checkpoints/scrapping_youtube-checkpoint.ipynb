# %% [markdown]
# # Scrapping YouTube videos
#
# @Raphael
#
# ## YouTube API
#
# In this class you will learn how to create a search engine for YouTube videos by an API.
# The documentation of YouTube API is here : https://developers.google.com/youtube/v3/docs/.
#
# * In order to make calls on Youtube API, you must provide a *key*. This key is requiered to retrieve *resources* and serves as a way to authentificate someone.
#
# * To retrieve a resource you need to create a *HTTP request* and send it to a specific API __url__. This can be done by using python package *requests*, cf. *requests.get(url, parameters, header)*.
#
# * By doing so, your request is then evaluated by YouTube API and a response is sent back to you. Typically, when the request is valid (use *is_valid_response*), a JSON is provided containing the resource requested.
#
# * To access a resource, you will need to create a HTTP request that contains a list of parameters defined by the resource you want to access :
#     - the API __key__
#     - one or several *required parameters*
#     - one or several *other parameters*
#
# Example: *https://www.googleapis.com/youtube/v3/search* (see doc. https://developers.google.com/youtube/v3/docs/search/list) allows to search for contents based on keywords. For this resource, it requires a parameter __part__ that specifies the type of properties you will retrieve.

# %%
import requests, json

# To build up a HTTP request, parameters will be encoded in JSON so you need to define a dictionary for that
parameters = {}
parameters["key"] = "AIzaSyDkICKG01px6a_jFXU9X9HsDc5tvOMDmK0"
parameters["part"] = "snippet" # you can use "id" instead of "part" to get only videoIDs
parameters["type"] = "video"
parameters["q"] = "surf pacific ocean"

response = requests.get("https://www.googleapis.com/youtube/v3/search", parameters, headers={'accept-encoding':'gzip'})

if response.status_code == requests.codes.ok:
    response_json = response.json()
    print(json.dumps(response_json, indent=2, sort_keys=True))
else:
    print("Malformed HTTP request")
# Out:
# {
#   "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/qVgV3cbbxZuT-xRmPHEAXC2vdb4\"",
#   "items": [
#     {
#       "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/zO1T6Z3T2tazDFnY-DgHOuQy7kE\"",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "kFjETSa9N7A"
#       },
#       "kind": "youtube#searchResult",
#       "snippet": {
#         "channelId": "UC--3c8RqSfAqYBdDjIG3UNA",
#         "channelTitle": "Red Bull Surfing",
#         "description": "Subscribe to our new Red Bull Surfing channel: https://win.gs/SubToRedBullSurfing The Indian Ocean's swell of the century hit Western Australia and absolutely ...",
#         "liveBroadcastContent": "none",
#         "publishedAt": "2015-07-22T18:30:01.000Z",
#         "thumbnails": {
#           "default": {
#             "height": 90,
#             "url": "https://i.ytimg.com/vi/kFjETSa9N7A/default.jpg",
#             "width": 120
#           },
#           "high": {
#             "height": 360,
#             "url": "https://i.ytimg.com/vi/kFjETSa9N7A/hqdefault.jpg",
#             "width": 480
#           },
#           "medium": {
#             "height": 180,
#             "url": "https://i.ytimg.com/vi/kFjETSa9N7A/mqdefault.jpg",
#             "width": 320
#           }
#         },
#         "title": "Indian Ocean Mega Swell Hits Australia | Filmers @ Large"
#       }
#     },
#     {
#       "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/dH5rl5_0_Xp7-cM7PCbbcoQK55g\"",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "CZR8Ac6OETE"
#       },
#       "kind": "youtube#searchResult",
#       "snippet": {
#         "channelId": "UCk2_9IBnLMvvtf62L3voi7Q",
#         "channelTitle": "wwwrebeltv",
#         "description": "http://www.facebook.com/rebeltelevision If you ever dreamt of leaving the 21st century behind... to step back into another world and time - you will catch sight of ...",
#         "liveBroadcastContent": "none",
#         "publishedAt": "2012-03-05T10:59:20.000Z",
#         "thumbnails": {
#           "default": {
#             "height": 90,
#             "url": "https://i.ytimg.com/vi/CZR8Ac6OETE/default.jpg",
#             "width": 120
#           },
#           "high": {
#             "height": 360,
#             "url": "https://i.ytimg.com/vi/CZR8Ac6OETE/hqdefault.jpg",
#             "width": 480
#           },
#           "medium": {
#             "height": 180,
#             "url": "https://i.ytimg.com/vi/CZR8Ac6OETE/mqdefault.jpg",
#             "width": 320
#           }
#         },
#         "title": "Surfers Paradise | Pacific Treasure - Solomon Islands - on REBEL.TV"
#       }
#     },
#     {
#       "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/kJim6fFOTUJiijNhpNIBI2Mm5HE\"",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "Wyp-Hjm5APY"
#       },
#       "kind": "youtube#searchResult",
#       "snippet": {
#         "channelId": "UCg9AX3Najn0RNExTUWHBr0Q",
#         "channelTitle": "dalesnale",
#         "description": "This natural ambiance audio of this Pacific Ocean recording has a steady surf pulse and detail of the foam and lapping on the sand. Captured late night into ...",
#         "liveBroadcastContent": "none",
#         "publishedAt": "2013-09-09T11:21:54.000Z",
#         "thumbnails": {
#           "default": {
#             "height": 90,
#             "url": "https://i.ytimg.com/vi/Wyp-Hjm5APY/default.jpg",
#             "width": 120
#           },
#           "high": {
#             "height": 360,
#             "url": "https://i.ytimg.com/vi/Wyp-Hjm5APY/hqdefault.jpg",
#             "width": 480
#           },
#           "medium": {
#             "height": 180,
#             "url": "https://i.ytimg.com/vi/Wyp-Hjm5APY/mqdefault.jpg",
#             "width": 320
#           }
#         },
#         "title": "Pacific Ocean Sound of Surf Waves - 7 Hours - Ambient Relaxation"
#       }
#     },
#     {
#       "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/K-M26ys6ZxZQoHAt-KmGdRvT3KU\"",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "cRrsgqY1IAw"
#       },
#       "kind": "youtube#searchResult",
#       "snippet": {
#         "channelId": "UCg9AX3Najn0RNExTUWHBr0Q",
#         "channelTitle": "dalesnale",
#         "description": "Four Hours Ambient Pacific Ocean Surf Waves for relaxation pleasure. Sit back, relax or sleep to the soothing surf sounds of the Pacific Ocean in Northern ...",
#         "liveBroadcastContent": "none",
#         "publishedAt": "2012-08-30T01:17:22.000Z",
#         "thumbnails": {
#           "default": {
#             "height": 90,
#             "url": "https://i.ytimg.com/vi/cRrsgqY1IAw/default.jpg",
#             "width": 120
#           },
#           "high": {
#             "height": 360,
#             "url": "https://i.ytimg.com/vi/cRrsgqY1IAw/hqdefault.jpg",
#             "width": 480
#           },
#           "medium": {
#             "height": 180,
#             "url": "https://i.ytimg.com/vi/cRrsgqY1IAw/mqdefault.jpg",
#             "width": 320
#           }
#         },
#         "title": "Pacific Ocean Sound of the Surf - Four Hours Ambient Audio  - Point Reyes"
#       }
#     },
#     {
#       "etag": "\"j6xRRd8dTPVVptg711_CSPADRfg/kKoDZr1_vjFgCzRVNoXTQuMy1Jw\"",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "lZoA5ZX4wC0"
#       },
#       "kind": "youtube#searchResult",
#       "snippet": {
#         "channelId": "UC-Zt7GPzlrPPQexkG9-shPg",
#         "channelTitle": "Surf Rinse Repeat",
#         "description": "Raw surfing video clips of Ocean Beach in San Francisco, CA 12-27-16 Buy Merch: https://teespring.com/stores/surfrinserepeat Surfers: Kolohe Andino, Luke ...",
#         "liveBroadcastContent": "none",
#         "publishedAt": "2017-12-04T07:18:50.000Z",
#         "thumbnails": {
#           "default": {
#             "height": 90,
#             "url": "https://i.ytimg.com/vi/lZoA5ZX4wC0/default.jpg",
#             "width": 120
#           },
#           "high": {
#             "height": 360,
#             "url": "https://i.ytimg.com/vi/lZoA5ZX4wC0/hqdefault.jpg",
#             "width": 480
#           },
#           "medium": {
#             "height": 180,
#             "url": "https://i.ytimg.com/vi/lZoA5ZX4wC0/mqdefault.jpg",
#             "width": 320
#           }
#         },
#         "title": "Ocean Beach Surfing Raw | San Francisco, CA"
#       }
#     }
#   ],
#   "kind": "youtube#searchListResponse",
#   "nextPageToken": "CAUQAA",
#   "pageInfo": {
#     "resultsPerPage": 5,
#     "totalResults": 1000000
#   },
#   "regionCode": "FR"
# }

# %% [markdown]
# For convenience, use the python class defined below and implement your code there.
#
# ### Exercice 1
# Implement *search_videos_by_tems* that gets a list of 20 videos from https://www.googleapis.com/youtube/v3/search.
# The method should return a list video IDs.
#
# ### Exercice 2
# Using the documentation, find the proper resource so you can implement *get_video_information* which retrieves information for a specific video (such as statistics (number of view and number of likes) and topic details (links to Wikipedia pages associated with the categories of the video)).
# The method should return a dictionary of video IDs (keys) with related information (values).
#
# ### Exercice 3
# Implement *get_most_similar_video* so it retrieves the top 5 most similar videos for a specific video (see *search* resource from API and use __relevance__ for *order* parameter). The method should return a list of video IDs. After calling this method for each of the 20 videos you will be able to build a network of videos where links depict similarity between videos.
#
# **Don't hesitate to print the JSON response to investigate the data structure.**

# %%
import requests, json

class youtube_api:
    api_key = "AIzaSyDkICKG01px6a_jFXU9X9HsDc5tvOMDmK0"
    http_header = {'accept-encoding':'gzip'}

    def is_valid_response(self, response):
        if response.status_code == requests.codes.ok:
            return True
        else:
            response_json = response.json()
            print "Error : %s\n" % (response_json["error"]["message"])
            return False

    def search_videos_by_tems(self, list_terms = []):
        # your code
    
    def get_information_video(self, video_id):
        # your code
    
    def get_most_similar_video(self, video_id):
        # your code
# Out:
#   File "<ipython-input-4-fcfbfb2c777f>", line 18
#     def get_information_video(self, video_id):
#       ^
# IndentationError: expected an indented block
